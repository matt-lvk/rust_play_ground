# %%
import pickle

# %%
import hull_white_py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import hull_white_py
#
# ModuleNotFoundError: No module named 'hull_white_py'

# %%
import matplotlib.pyplot as plt


# Plot the list
plt.plot(list)
plt.title('Plot of List')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
list
# Out:
# [0.0,
#  0.09987569236845958,
#  0.20074607335200043,
#  0.3026283566131638,
#  0.4055586851885208,
#  0.5094664923419658,
#  0.6144688486401882,
#  0.7205005194931191,
#  0.827641704193332,
#  0.9360704471646121,
#  1.045420684292998,
#  1.1559212178441056,
#  1.2674908617938319,
#  1.3801183583979235,
#  1.4939173143398499,
#  1.6087852069299797,
#  1.72480093662432,
#  1.8421985823412703,
#  1.9604959692237833,
#  2.080261517329714,
#  2.2011141862833132,
#  2.322950934902839,
#  2.446149881375949,
#  2.5707417084785984,
#  2.696486125427721,
#  2.82352876233063,
#  2.951672507598974,
#  3.0811964486752186,
#  3.2121251873760035,
#  3.3442177837033253,
#  3.477798837522581,
#  3.6125399841764914,
#  3.748478600087032,
#  3.886195269621178,
#  4.024989430130806,
#  4.165279232259612,
#  4.307051286599639,
#  4.450074873690263,
#  4.594362091455803,
#  4.740337802794493,
#  4.887814404200422,
#  5.036665447857365,
#  5.186975348738129,
#  5.338799832430537,
#  5.492201494326287,
# ...
